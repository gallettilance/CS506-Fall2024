# %% [markdown]
# # Worksheet
#
# [FORM](https://forms.gle/RkRnte1rVThG6yJm8)
#
# ## Regression

# %%
import numpy as np
import tensorflow.keras as keras

from kviz.visualizer import Visualizer

from importlib.metadata import version
assert version('kviz') == '0.0.11'

TEMPFILE_NAME = "temp.png"

model = keras.models.Sequential()
model.add(keras.layers.Dense(10, input_dim=1, activation='sigmoid'))
model.add(keras.layers.Dense(10, activation='relu'))
model.add(keras.layers.Dense(1, activation=None))
model.compile(loss="mean_squared_error")

SAMPLE_SIZE = 200
X = (-10.0 + 20.0 * np.random.random(SAMPLE_SIZE)).reshape(-1, 1)
Y = -2 + 3 * X + 5 * np.cos(X) + np.random.randn(SAMPLE_SIZE) * 2

dg = Visualizer(model)
dg.fit(X, Y, 100, 'test_regression', 100, epochs=10000, verbose=0, batch_size=200)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 22
#      19 Y = -2 + 3 * X + 5 * np.cos(X) + np.random.randn(SAMPLE_SIZE) * 2
#      21 dg = Visualizer(model)
# ---> 22 dg.fit(X, Y, 100, 'test_regression', 100, epochs=10000, verbose=0, batch_size=200)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kviz/visualizer.py:341, in fit(self, X, Y, snap_freq, filename, duration, **kwargs)
#     324 def fit(self, X, Y, snap_freq=10, filename='decision_boundary', duration=1000, **kwargs):
#     325     """
#     326     Make GIF from snapshots of decision boundary at given snap_freq of epochs during training
#     327
#     328     Parameters:
#     329         X : ndarray
#     330             input to a Keras model
#     331         Y : ndarray
#     332             classes to be learned
#     333         snap_freq : int
#     334             number of epochs after which to take a snapshot
#     335         filename : str
#     336             name of file to save as GIF
#     337         duration : int
#     338             duration in ms between images in GIF
#     339         **kwargs : other params
#     340             paramter inputs to model.fit
# --> 341
#     342     Returns:
#     343         The model after learning
#     344     """
#     346     images = []
#     347     if 'epochs' in kwargs:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kviz/visualizer.py:225, in _snap_decision_boundary(self, X, Y, filename)
#     222 y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
#     223 xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
#     224                      np.arange(y_min, y_max, h))
# --> 225 meshData = np.c_[xx.ravel(), yy.ravel()]
#     227 fig, ax = plt.subplots(frameon=False)
#     228 ax.scatter(X[:, 0], X[:, 1], color=COLORS[Y].tolist(), s=100, alpha=.9)
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %% [markdown]
# ## Initialization

# %%
from tensorflow.keras.initializers import Zeros
import sklearn.datasets as datasets

np.random.seed(1)

CENTERS = [[0, 0]]
DATA, _ = datasets.make_blobs(
        n_samples=200,
        centers=CENTERS,
        cluster_std=1,
        random_state=1
    )

cw1 = -1 
cw2 = 1
cb = -1

sw1 = -1
sw2 = 1
sb = 1

X = np.array(list(filter(lambda x : cw1 * x[0] + cw2 * x[1] + cb < -.5 or cw1 * x[0] + cw2 * x[1] + cb > .5, DATA)))
X = np.array(list(filter(lambda x : sw1 * x[0] + sw2 * x[1] + sb < -.5 or sw1 * x[0] + sw2 * x[1] + sb > .5, X)))
C = np.array([0 if cw1 * x[0] + cw2 * x[1] + cb >= 0 else 1 for x in X])
S = np.array([0 if sw1 * x[0] + sw2 * x[1] + sb >= 0 else 1 for x in X])
pass_fail = C ^ S

model = keras.models.Sequential()
model.add(keras.layers.Dense(2, input_dim=2, activation="sigmoid", kernel_initializer=Zeros(), bias_initializer=Zeros()))
model.add(keras.layers.Dense(1, activation="sigmoid", kernel_initializer=Zeros(), bias_initializer=Zeros()))
model.compile(loss="binary_crossentropy")

viz = Visualizer(model)
viz.fit(X, C, 1, 'zeroes', 100, epochs=100)

# for l in model.layers:
#         print(l.get_weights())
# for i in range(100):
#     model.fit(X, C, epochs=1, batch_size=200)
#     for l in model.layers:
#         print(l.get_weights())
# Out:
# /Users/lance/Documents/BostonUniversity/Data-Science-Fundamentals/env/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - loss: 0.6921
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 167us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.6890
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 164us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 0.6852
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 163us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.6840
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 160us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.6812
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 199us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.6806
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 0.6773
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 161us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.6759
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 161us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - loss: 0.6745
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 221us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.6704
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - loss: 0.6663
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - loss: 0.6719
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 163us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.6686
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.6638
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - loss: 0.6631
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.6597
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 163us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.6602
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.6599
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - loss: 0.6534
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 160us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - loss: 0.6578
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 173us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.6560
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - loss: 0.6467
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.6506
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.6405
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 166us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6564
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 160us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.6530
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - loss: 0.6400
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 167us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.6419
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 159us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.6375
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 162us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.6402
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 166us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.6326
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 163us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.6392
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.6339
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 195us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6296
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6228
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.6315
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 159us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6270
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.6241
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 161us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.6210
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.6253
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 159us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.6099
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.6094
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.6310
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.6137
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.6161
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 161us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.6171
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6175
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.6004
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.5983
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.6088
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.6055
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.5969
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 164us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.5955
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 159us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.6071
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.5913
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 162us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.5913
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.5922
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.6054
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 161us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.5905
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.5865
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.5779
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.5729
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.5952
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.5833
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.5842
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 201us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.5886
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.5873
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.5625
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 162us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.5712
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.5746
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.5762
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 162us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.5741
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.5818
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.5855
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 162us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.5525
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.5832
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.5670
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 161us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.5585
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.5707
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 0.5797
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 161us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.5704
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.5679
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.5539
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 162us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.5749
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 160us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.5477
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 159us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.5468
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 162us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.5519
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.5534
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.5514
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 163us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.5341
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.5720
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 159us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.5405
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 163us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.5694
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 159us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.5800
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.5579
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.5438
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.5417
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 162us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.5489
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 157us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.5441
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 158us/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.5495
# 3335/3335 ━━━━━━━━━━━━━━━━━━━━ 1s 161us/step
# <Sequential name=sequential_357, built=True>
